# %% [markdown]
# # Play Store Analysis

# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns

# %%
os.chdir('C:/Users/soumya/Desktop/BI/phython')

# %%
df= pd.read_csv('playstore-analysis (2) (1).csv')
df.head().T
# Out:
#                                                              0  \
# App             Photo Editor & Candy Camera & Grid & ScrapBook
# Category                                        ART_AND_DESIGN
# Rating                                                     4.1
# Reviews                                                    159
# Size                                                     19000
# Installs                                               10,000+
# Type                                                      Free
# Price                                                        0
# Content Rating                                        Everyone
# Genres                                            Art & Design
# Last Updated                                   January 7, 2018
# Current Ver                                              1.0.0
# Android Ver                                       4.0.3 and up
#
#                                         1  \
# ...

# %%
df.tail()
# Out:
#                                                  App             Category  \
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews          Size     Installs  Type Price Content Rating  \
# 10836     4.5      38  53000.000000       5,000+  Free     0       Everyone
# 10837     5.0       4   3600.000000         100+  Free     0       Everyone
# 10838     NaN       3   9500.000000       1,000+  Free     0       Everyone
# 10839     4.5     114  21516.529524       1,000+  Free     0     Mature 17+
# 10840     4.5  398307  19000.000000  10,000,000+  Free     0       Everyone
#
# ...

# %% [markdown]
# # BASIC OF DATA-SET PROVIDED

# %%
df.shape
# Out:
# (10841, 13)

# %%
print(df.columns)
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  float64
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(2), object(11)
# memory usage: 1.1+ MB

# %%
df.nunique()
# Out:
# App               9660
# Category            34
# Rating              40
# Reviews           6002
# Size               460
# Installs            22
# Type                 3
# Price               93
# Content Rating       6
# Genres             120
# Last Updated      1378
# Current Ver       2832
# Android Ver         33
# dtype: int64

# %%
df.describe(include = 'all')
# Out:
#            App Category       Rating Reviews           Size    Installs  \
# count    10841    10841  9367.000000   10841   10841.000000       10841
# unique    9660       34          NaN    6002            NaN          22
# top     ROBLOX   FAMILY          NaN       0            NaN  1,000,000+
# freq         9     1972          NaN     596            NaN        1579
# mean       NaN      NaN     4.193338     NaN   21516.529524         NaN
# std        NaN      NaN     0.537431     NaN   20746.537567         NaN
# min        NaN      NaN     1.000000     NaN       8.500000         NaN
# 25%        NaN      NaN     4.000000     NaN    5900.000000         NaN
# 50%        NaN      NaN     4.300000     NaN   18000.000000         NaN
# 75%        NaN      NaN     4.500000     NaN   26000.000000         NaN
# max        NaN      NaN    19.000000     NaN  100000.000000         NaN
#
#          Type  Price Content Rating Genres    Last Updated  \
# ...

# %%
df.describe().T
# Out:
#           count          mean           std  min     25%      50%      75%  \
# Rating   9367.0      4.193338      0.537431  1.0     4.0      4.3      4.5
# Size    10841.0  21516.529524  20746.537567  8.5  5900.0  18000.0  26000.0
#
#              max
# Rating      19.0
# Size    100000.0

# %% [markdown]
# ### 1.  Data clean up – Missing value treatment
#
# ### a. Drop records where rating is missing since rating is our target/study variable
#
# ### b. Check the null values for the Android Ver column.
# i. Are all 3 records having the same problem?
# ii. Drop the 3rd record i.e. record for “Life Made WIFI …”
# iii. Replace remaining missing values with the mode
#
# ### c. Current ver – replace with most common value -->

# %%
df.isnull().sum() # among 10841 rows, 1474 contains zero
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
df.dropna(how = 'any',subset = ["Rating"], inplace = True)

# %%
df.drop([10472], axis=0,inplace = True)
df.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       4
# Android Ver       2
# dtype: int64

# %%
modeof_adver = str(df["Android Ver"].mode())
df["Android Ver"].fillna(value = modeof_adver, inplace = True)
df.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       4
# Android Ver       0
# dtype: int64

# %%
modeof_currentver = df["Current Ver"].mode()[0]
df["Current Ver"].fillna(value = modeof_currentver, inplace = True)
print("Null values: ",df.isnull().sum().sum())
# Out:
# Null values:  0

# %%
df.shape
# Out:
# (9366, 13)

# %%
df.iloc[10:20, 10:12] #Its now updated with most common value
# Out:
#         Last Updated         Current Ver
# 10  October 27, 2017               1.0.4
# 11     July 31, 2018              1.0.15
# 12     April 2, 2018                 3.8
# 13     June 26, 2018               1.0.4
# 14    August 3, 2018               1.2.3
# 15      June 6, 2018  Varies with device
# 16     July 31, 2018                 3.1
# 17  November 7, 2017                 1.0
# 18    August 3, 2018               2.2.5
# 19     July 30, 2018               5.5.4

# %%
df.iloc[1550:1559, 8:12]  #Its now updated with most common value
# Out:
#      Content Rating     Genres        Last Updated Current Ver
# 1632       Everyone  Lifestyle  September 27, 2016         2.0
# 1633       Everyone  Lifestyle       July 30, 2018       4.1.0
# 1634       Everyone  Lifestyle   February 20, 2018         6.1
# 1635       Everyone  Lifestyle       July 26, 2018       9.1.0
# 1636       Everyone  Lifestyle    October 12, 2017       3.9.5
# 1637       Everyone  Lifestyle  September 27, 2016       2.2.6
# 1638       Everyone  Lifestyle       July 13, 2018      12.1.0
# 1639       Everyone  Lifestyle       July 27, 2018       8.3.3
# 1640       Everyone  Lifestyle       April 9, 2018    5.600.42

# %% [markdown]
# ### 2. Data clean up – correcting the data types
# ### a. Which all variables need to be brought to numeric types?
# ### b. Price variable – remove $ sign and convert to float
# ### c. Installs – remove ‘,’ and ‘+’ sign, convert to integer
# ### d. Convert all other identified columns to numeric

# %%
#To be brought to numeric - Reviews, price,Installs

# %%
df['Reviews'] = df['Reviews'].astype(int) # Reviews

# %%
df['Price'] = df['Price'].replace({'\$':''}, regex = True) # Price
df['Price'] = df['Price'].astype(float)

# %%
df['Installs']=df['Installs'].str.replace('+','') # Installs
df['Installs']=df['Installs'].str.replace(',','')
df['Installs'] = df['Installs'].astype(int)

# %%
#Its now converted 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9366 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             9366 non-null   object
#  1   Category        9366 non-null   object
#  2   Rating          9366 non-null   float64
#  3   Reviews         9366 non-null   int32
#  4   Size            9366 non-null   float64
#  5   Installs        9366 non-null   int32
#  6   Type            9366 non-null   object
#  7   Price           9366 non-null   float64
#  8   Content Rating  9366 non-null   object
#  9   Genres          9366 non-null   object
#  10  Last Updated    9366 non-null   object
#  11  Current Ver     9366 non-null   object
#  12  Android Ver     9366 non-null   object
# dtypes: float64(3), int32(2), object(8)
# memory usage: 951.2+ KB

# %% [markdown]
# ### 3. Sanity checks – check for the following and handle accordingly
# ### a. Avg. rating should be between 1 and 5, as only these values are allowed on the play store.
# ### i. Are there any such records? Drop if so.
# ### b. Reviews should not be more than installs as only those who installed can review the app.
# ### Are there any such records? Drop if so.

# %%
df[df.Rating > 5] #none is greater than 5
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %%
df[df.Rating < 1 ] #none less than 1
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %%
df[df.Reviews > df.Installs] # identifying columns where reviews is greater than install - 7 colums
# Out:
#                                  App   Category  Rating  Reviews  \
# 2454             KBA-EZ Health Guide    MEDICAL     5.0        4
# 4663   Alarmy (Sleep If U Can) - Pro  LIFESTYLE     4.8    10249
# 5917                        Ra Ga Ba       GAME     5.0        2
# 6700                Brick Breaker BR       GAME     5.0        7
# 7402            Trovami se ci riesci       GAME     5.0       11
# 8591                         DN Blog     SOCIAL     5.0       20
# 10697                        Mu.F.O.       GAME     5.0        2
#
#                Size  Installs  Type  Price Content Rating     Genres  \
# 2454   25000.000000         1  Free   0.00       Everyone    Medical
# 4663   21516.529524     10000  Paid   2.49       Everyone  Lifestyle
# 5917   20000.000000         1  Paid   1.49       Everyone     Arcade
# 6700   19000.000000         5  Free   0.00       Everyone     Arcade
# 7402    6100.000000        10  Free   0.00       Everyone     Arcade
# ...

# %%
df.drop(df[df.Reviews> df.Installs].index, inplace =True)
df.shape
# Out:
# (9359, 13)

# %% [markdown]
# ### Identify and handle outliers –
# ### a. Price column
# ### i. Make suitable plot to identify outliers in price
# ### ii. Do you expect apps on the play store to cost dollar 200? Check out these cases
# ### iii. After dropping the useless records, make the suitable plot again to identify outliers
# ### iv. Limit data to records with price < $30

# %%
df.boxplot()

# %%
df.boxplot('Price')

# %%
df.drop(df[df.Price>200].index, inplace = True) #16 were more than 200
df.shape
# Out:
# (9344, 13)

# %%
df.boxplot('Price') # all under 200 now

# %%
df.drop(df[df.Price>30].index, inplace = True) #6 were more than 30
df.shape
# Out:
# (9338, 13)

# %%
df.boxplot('Price') # all under 30 now

# %% [markdown]
# ### b. Reviews column
# ### i. Make suitable plot
# ### 3 ii. Limit data to apps with < 1 Million reviews

# %%
df.boxplot('Reviews')

# %%
Z = df[df['Reviews']>1000000].index.to_list()

# %%
df.drop(Z, inplace = True)
df.shape
# Out:
# (8634, 13)

# %%
df.boxplot('Reviews') # All data points under 1 mn

# %% [markdown]
# ### c. Installs
# ### i. What is the 95th percentile of the installs?
# ### ii. Drop records having a value more than the 95th percentile

# %%
np.percentile(df['Installs'], 95)
# Out:
# 10000000.0

# %%
s = df[df['Installs']>10000000].index.to_list()

# %%
df.drop(s, inplace = True)
df.shape
# Out:
# (8435, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8435 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             8435 non-null   object
#  1   Category        8435 non-null   object
#  2   Rating          8435 non-null   float64
#  3   Reviews         8435 non-null   int32
#  4   Size            8435 non-null   float64
#  5   Installs        8435 non-null   int32
#  6   Type            8435 non-null   object
#  7   Price           8435 non-null   float64
#  8   Content Rating  8435 non-null   object
#  9   Genres          8435 non-null   object
#  10  Last Updated    8435 non-null   object
#  11  Current Ver     8435 non-null   object
#  12  Android Ver     8435 non-null   object
# dtypes: float64(3), int32(2), object(8)
# memory usage: 856.7+ KB

# %% [markdown]
# ### Data analysis to answer business questions
# ### 5. What is the distribution of ratings like? (use Seaborn) More skewed towards higher/lower values?
# ### a. How do you explain this?
# ### b. What is the implication of this on your analysis?

# %%
sns.distplot(df['Rating'], bins = 10)
plt.show()

# %%
data = df[['Rating']]
plt.violinplot(data.values)
plt.show()

# %%
# The implications of this is that data is left skewed, which is positively skewed. 
# Therefore, majority of records are higher rated

# %% [markdown]
# ### 6. What are the top Content Rating values?
# ### a. Are there any values with very few records?
# ### b. If yes, drop those as they won’t help in the analysis

# %%
df['Content Rating'].value_counts()
# Out:
# Everyone           6782
# Teen                900
# Mature 17+          417
# Everyone 10+        332
# Adults only 18+       3
# Unrated               1
# Name: Content Rating, dtype: int64

# %%
Adult_rating = df[df['Content Rating'] == 'Adults only 18+'].index.to_list()

# %%
unrated =df[df['Content Rating'] == 'Unrated'].index.to_list()

# %%
df.drop(Adult_rating, inplace = True)

# %%
df.drop(unrated, inplace = True)

# %%
df['Content Rating'].value_counts()
# Out:
# Everyone        6782
# Teen             900
# Mature 17+       417
# Everyone 10+     332
# Name: Content Rating, dtype: int64

# %% [markdown]
# ### 7. Effect of size on rating
# ### a. Make a joinplot to understand the effect of size on rating
# ### b. Do you see any patterns?
# ### c. How do you explain the pattern?

# %%
sns.jointplot('Rating', 'Size', data = df, color = 'g')

# %%
sns.jointplot('Rating', 'Size', data = df[:100], color = 'r')

# %%
sns.heatmap(df.corr(), annot = True)
plt.show()

# %%
# 7.b>>> Yes, there is a pattern. The higer bulk of data is situated around low-size, high-rating. 
#Therefore, the rating increases,size increases

# %%
# 7.c>>>  Positive Co-relation. But it is weak (0.058) as per Heatmap.

# %% [markdown]
# ### 8. Effect of price on rating
# ### a. Make a jointplot (with regression line)
# ### b. What pattern do you see?
# ### c. How do you explain the pattern?
# ### d. Replot the data, this time with only records with price > 0
# ### e. Does the pattern change?
# ### f. What is your overall inference on the effect of price on the rating

# %%
sns.jointplot(x ="Rating" , y = "Price" ,data = df )
plt.show()

# %%
sns.regplot(x="Price", y="Rating", data=df, color ='c');

# %%
sns.lmplot(x='Price', y='Rating', hue ='Content Rating', data=df);

# %%
sns.lmplot(x='Price', y='Rating', hue ='Type', data=df);

# %%
sns.lmplot(x='Price', y='Rating', hue ='Category', data=df);

# %%
# 8 b.>>> On increasing the price, Rating Increases. However, the co-relations is different for different
#content rating,type and category.
#e.g. Mature and Teen are more posively co-related in Content rating than 10+ and everyone 

# 8.C >>> There is a weak -correlation and that co-relation varies with Content rating, Type and Category

# %%
Price_greaterthan_zero = df[df['Price'] > 0]

# %%
sns.regplot(x='Price', y='Rating', data = Price_greaterthan_zero);

# %%
sns.jointplot(x ="Rating" , y = "Price" ,data = Price_greaterthan_zero, kind = "reg" )
plt.show()

# %%
Price_lessthan_zero = df[df['Price'] == 0]

# %%
sns.jointplot(x ="Rating" , y = "Price" ,data = Price_lessthan_zero, kind = "reg", color ='y' )
plt.show()
# Out:
# C:\Users\soumya\anaconda3\lib\site-packages\seaborn\distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)

# %%
# 8.e>>> Yes, Pattern changes as no relation exists for Price less the Zero

# 8.f>>> Overall, Price has no co-relation with rating for Zero prices application. 
#However the co-relation is weakly positive for paid apps. In paid apps also, it changes with different 
#catergories, Content Ratings

# %% [markdown]
# ### 9. Look at all the numeric interactions together –
# ### a. Make a pairplort with the colulmns - 'Reviews', 'Size', 'Rating', 'Price'

# %%
sns.pairplot(df, vars=['Reviews', 'Size', 'Rating', 'Price'], kind = 'reg', hue ='Type')
plt.show()
# Out:
# C:\Users\soumya\anaconda3\lib\site-packages\seaborn\distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ### 10. Rating vs. content rating
# ### a. Make a bar plot displaying the rating for each content rating
# ### b. Which metric would you use? Mean? Median? Some other quantile?
# ###  c. Choose the right metric and plot

# %%
a = df['Rating'].groupby(df['Content Rating']).median().plot(kind = 'bar')
a.set(xlabel ='Rating of content', ylabel = 'Average of Ratings')
plt.show()

 # I will choose median because our data is positivey skewed. Mean would have been suitable if it were normally distributed.

# %%
df.groupby(['Content Rating'])['Rating'].count().plot.bar(color="b")
plt.ylabel('Rating')
plt.show()

# %% [markdown]
# ### 11. Content rating vs. size vs. rating – 3 variables at a time
# ### a. Create 5 buckets (20% records in each) based on Size
# ### b. By Content Rating vs. Size buckets, get the rating (20th percentile) for each combination
# ### c. Make a heatmap of this i. Annotated ii. Greens color map
# ### d. What’s your inference? Are lighter apps preferred in all categories? Heavier? Some?

# %%
sns.distplot(df["Size"], bins=5)
plt.show()

# %%
sns.heatmap(df.corr(), annot = True )
plt.show()

# %%
sns.heatmap(df.corr(), cmap="Greens", annot = True )
plt.show()

# %%
# Creating 5 bins

df.Size.quantile([0.2, 0.4,0.6,0.8])
# Out:
# 0.2     4600.000000
# 0.4    12000.000000
# 0.6    21516.529524
# 0.8    32000.000000
# Name: Size, dtype: float64

# %%
print('The Min of the Size is', df.Size.min())
print('the Max of the Size is', df.Size.max())
# Out:
# The Min of the Size is 8.5
# the Max of the Size is 100000.0

# %%
bins=[0, 4600, 12000, 21516, 32000, 100000]
df['Size_Buckets'] = pd.cut(df['Size'], bins, labels=['VERY LOW','LOW','MED','HIGH','VERY HIGH'])
pd.pivot_table(df, values='Rating', index='Size_Buckets', columns='Content Rating')
# Out:
# Content Rating  Everyone  Everyone 10+  Mature 17+      Teen
# Size_Buckets
# VERY LOW        4.116465      4.188889    3.951429  4.216129
# LOW             4.158147      4.207143    4.129592  4.208511
# MED             4.178139      4.300000    3.883582  4.123973
# HIGH            4.213706      4.199174    4.163333  4.170435
# VERY HIGH       4.185690      4.215702    4.193814  4.244483

# %%
Size_Buckets =pd.pivot_table(df, values='Rating', index='Size_Buckets', columns='Content Rating', 
                     aggfunc=lambda x:np.quantile(x,0.2))
Size_Buckets
# Out:
# Content Rating  Everyone  Everyone 10+  Mature 17+  Teen
# Size_Buckets
# VERY LOW             3.8          3.84        3.28  3.84
# LOW                  3.8          3.94        3.64  3.80
# MED                  3.9          4.16        3.50  3.90
# HIGH                 4.0          4.00        3.98  3.90
# VERY HIGH            3.9          4.00        4.00  4.00

# %%
sns.heatmap(Size_Buckets, annot = True)

# %%
sns.heatmap(Size_Buckets, annot=True, cmap='Greens')
plt.show()

# %%
# 11.D>>>> Yes, heavier apps seems to be more preferred in all the Content Ratings. But, not to a large variations.  
#Except, Mature 17+ where low size apps arent preferred to a greater variation
